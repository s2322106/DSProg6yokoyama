# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#よくわからない
#import japanize-matplotlib
import sqlite3

# %%
# データベースからデータを取得
con = sqlite3.connect("/Users/hiro/assignment/DSpfinal/DSProg6yokoyama/tests.db")
query = "SELECT * FROM average_moneys"
df1 = pd.read_sql_query(query, con)
con.close()

con = sqlite3.connect("/Users/hiro/assignment/DSpfinal/DSProg6yokoyama/mydata.db")
query = "SELECT * FROM my_money"
df2 = pd.read_sql_query(query, con)
con.close()


# データをグラフ化
plt.bar(df1['name'], df1['money'], label='一人暮らし平均')
plt.bar(df2['name'], df2['money'], bottom=df1['money'], label='個人平均')

plt.legend()
plt.show()
